# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\Mouna\\OneDrive\\Pictures\\Desktop\\remade.csv")


df1 = df.copy(deep=True)
df1 = df1.drop(['the_geom','the_geom_webmercator','cartodb_id','rw_country_code','rw_country_name','country',
                'cri_rank','fatalities_per_100k_rank','fatalities_rank','losses_per_gdp__rank','losses_usdm_ppp_rank','world_label'],axis=1)

df1["losses_per_gdp__total"].fillna(0,inplace=True)

X = df1.iloc[:,2: ]
y = df1.iloc[:,1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
sreg = SVR(kernel='linear')

# %%
sreg.fit(X_train_scaled,y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred = sreg.predict(X_test_scaled)

# %%
print(y_pred)
# Out:
# [85.40914664 85.40914664 83.79728847 85.21307813 84.6564623  81.29767458
#  85.07072622 82.5832384  85.05831981 85.40914664 84.4665386  85.28817839
#  66.15002828 83.91411676 84.26484484 85.32846376 85.40914664 85.31596056
#  85.40914664 55.49997431 71.9852576  75.49440281 85.19827652 85.40914664
#  85.36830263 85.40914664 73.28298332 85.16640654 85.33485439 85.40914664
#  84.36524491 84.68429468 84.23072754 28.11996887 85.40914664 85.40914664
#  84.79867392]

# %%
ms_score = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
print(np.sqrt(ms_score))
print(np.sqrt(r2))
# Out:
# 29.889021937566564
# 0.47734773627022203

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Plot")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], linestyle='--', color='red')
plt.show()

# %%
sreg = SVR(kernel='poly', degree=2,C=1)
sreg.fit(X_train_scaled,y_train)
# Out:
# SVR(C=1, degree=2, kernel='poly')

# %%
y_pred = sreg.predict(X_test_scaled)
print(y_pred)
# Out:
# [77.59841307 77.59841307 77.55701145 77.5997922  77.59604074 77.17944168
#  77.60033052 77.36748725 77.59986863 77.59841307 77.5924989  77.59912391
#  69.75397197 77.56015428 77.60258892 77.59903534 77.59841307 77.59987833
#  77.59841307 53.21258185 75.43908813 76.641844   77.60086152 77.59841307
#  77.59889971 77.59841307 72.94341646 77.60056081 77.59816129 77.59841307
#  77.60006449 77.60251658 77.59719299 36.56152832 77.59841307 77.59841307
#  77.60121389]

# %%
ms_score = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
print(np.sqrt(ms_score))
print(np.sqrt(r2))
# Out:
# 32.33841612009941
# 0.31003604094660037

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Plot")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], linestyle='--', color='red')
plt.show()

# %%
sreg = SVR(kernel='rbf')
sreg.fit(X_train_scaled,y_train)
# Out:
# SVR()

# %%
y_pred = sreg.predict(X_test_scaled)
print(y_pred)
# Out:
# [77.83984881 77.83984881 75.96555197 77.6557111  77.03330768 72.73092028
#  77.56584416 74.31197074 77.50261243 77.83984881 76.81775291 77.74502504
#  70.8942771  76.18665786 76.88272186 77.78105338 77.83984881 77.7429102
#  77.83984881 70.68738082 70.63278808 70.67780923 77.61769905 77.83984881
#  77.80658746 77.83984881 70.89692966 77.64713352 77.79064718 77.83984881
#  76.89566065 77.23084473 76.79072204 70.88701642 77.83984881 77.83984881
#  77.30961481]

# %%
ms_score = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
print(np.sqrt(ms_score))
print(np.sqrt(r2))
# Out:
# 32.5309292422467
# 0.29211060441730474

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Plot")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], linestyle='--', color='red')
plt.show()
